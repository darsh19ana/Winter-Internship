# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import sqlite3 as sql

# %% [markdown]
# ### Creating the connection

# %%
conn = sql.connect(r"C:\Users\darsh\OneDrive\Desktop\Week 5\sql-murder-mystery.db")

# %% [markdown]
# ### Queries

# %% [markdown]
# #### Query 1.  Retrieve Crime Scene Report
# Task: Run a query to retrieve the crime scene report for the murder that occurred on Jan.15, 2018, in SQL City. Gather all available details from the report.

# %%
query1 = """
SELECT * 
FROM
crime_scene_report
"""
pd.read_sql_query(query1,conn)
# Out:
#           date     type                                        description  \
# 0     20180115  robbery  A Man Dressed as Spider-Man Is on a Robbery Spree
# 1     20180115   murder                  Life? Dont talk to me about life.
# 2     20180115   murder  Mama, I killed a man, put a gun against his he...
# 3     20180215   murder                         REDACTED REDACTED REDACTED
# 4     20180215   murder  Someone killed the guard! He took an arrow to ...
# ...        ...      ...                                                ...
# 1223  20180430  bribery                                                 \n
# 1224  20180430    fraud                  ‘Why not?’ said the March Hare.\n
# 1225  20180430  assault                                                 \n
# 1226  20180501  assault  be NO mistake about it: it was neither more no...
# 1227  20180115   murder  Security footage shows that there were 2 witne...
#
#               city
# 0              NYC
# 1           Albany
# 2             Reno
# 3         SQL City
# 4         SQL City
# ...            ...
# 1223  Garden Grove
# 1224         Houma
# 1225       Fontana
# 1226       Trenton
# 1227      SQL City
#
# [1228 rows x 4 columns]

# %%
query2 = """
SELECT * 
FROM
crime_scene_report
WHERE
date = 20180115
AND 
type = "murder"
"""
pd.read_sql_query(query2,conn)
# Out:
#        date    type                                        description  \
# 0  20180115  murder                  Life? Dont talk to me about life.
# 1  20180115  murder  Mama, I killed a man, put a gun against his he...
# 2  20180115  murder  Security footage shows that there were 2 witne...
#
#        city
# 0    Albany
# 1      Reno
# 2  SQL City

# %% [markdown]
# #### Query 2. Witness Personal Details:
# Task: Check the personal details of witnesses involved in the case. Retrieve their names, addresses, and any other relevant information.

# %%
query3 = """
SELECT * 
FROM
person
WHERE
address_street_name
LIKE
"Northwestern Dr%"
ORDER BY
address_number desc
"""
pd.read_sql_query(query3,conn)
# Out:
#        id                  name  license_id  address_number  \
# 0   14887        Morty Schapiro      118009            4919
# 1   17729        Lasonya Wildey      439686            3824
# 2   53890        Sophie Tiberio      957671            3755
# 3   73368        Torie Thalmann      773862            3697
# 4   96595         Coretta Cubie      303645            3631
# 5   19420           Cody Schiel      890431            3524
# 6   93509        Emmitt Aceuedo      916706            3491
# 7   87456   Leonora Wolfsberger      215868            3483
# 8   36378        Freddie Ellzey      267882            3449
# 9   53076           Boris Bijou      664914            3327
# 10  28360        Rashad Cascone      924517            3212
# 11  23044          Val Portlock      924989            3143
# 12  51114     Christena Saffell      814284            3055
# 13  68690            Yer Modest      852404            3046
# 14  44004           Alison Eska      327797            2951
# 15  98593           Jonah Toner      578982            2947
# 16  59307          Cyril Yongue      753524            2903
# 17  34155      Allyson Lazenson      814209            2840
# 18  90397     Dionna Kranwinkle      797260            2678
# 19  54564         Sammie Sengun      217286            2590
# 49     Northwestern Dr  635287661

# %% [markdown]
# Thus, as we see, the name of the first witness is "Morty Schapiro". Now, we will try finding information about the second witness.

# %%
query4 = """
SELECT * 
FROM
person
WHERE
name 
LIKE
"Annabel%"
AND 
address_street_name 
LIKE
"Franklin Ave%"
"""
pd.read_sql_query(query4,conn)
# Out:
#       id            name  license_id  address_number address_street_name  \
# 0  16371  Annabel Miller      490173             103        Franklin Ave
#
#          ssn
# 0  318771143

# %% [markdown]
# #### Query 3. View Witness Interviews:
# Task: Access the recorded interviews of witnesses conducted after the murder. Gather insights into their statements and potential clues.

# %%
query5 = """
SELECT
* 
FROM 
interview
WHERE 
person_id IN (16371, 14887);
"""
pd.read_sql_query(query5,conn)
# Out:
#    person_id                                         transcript
# 0      14887  I heard a gunshot and then saw a man run out. ...
# 1      16371  I saw the murder happen, and I recognized the ...

# %% [markdown]
# #### Query 4. Check Gym Database:
# Task: Investigate the gym database using details obtained from the crime scene report and witness interviews. Look for any gym-related information that might be relevant.

# %%
query6 = """
SELECT
* 
FROM 
get_fit_now_member
"""
pd.read_sql_query(query6,conn)
# Out:
#         id  person_id                name  membership_start_date  \
# 0    NL318      65076     Everette Koepke               20170926
# 1    AOE21      39426        Noe Locascio               20171005
# 2    2PN28      63823  Jeromy Heitschmidt               20180215
# 3    0YJ24      80651      Waneta Wellard               20171206
# 4    3A08L      32858        Mei Bianchin               20170401
# ..     ...        ...                 ...                    ...
# 179  2V137      41693      Wendell Dulany               20171219
# 180  4KB72      79110          Emile Hege               20170522
# 181  48Z7A      28819        Joe Germuska               20160305
# 182  48Z55      67318       Jeremy Bowers               20160101
# 183  90081      16371      Annabel Miller               20160208
#
#     membership_status
# 0                gold
# 1             regular
# 2              silver
# 3                gold
# 4              silver
# ..                ...
# 179            silver
# 180           regular
# 181              gold
# 182              gold
# 183              gold
#
# [184 rows x 5 columns]

# %%
query7 = """
SELECT
* 
FROM 
get_fit_now_member
WHERE
membership_status = "gold"
AND 
id
LIKE
"48Z%"
"""
pd.read_sql_query(query7,conn)
# Out:
#       id  person_id           name  membership_start_date membership_status
# 0  48Z7A      28819   Joe Germuska               20160305              gold
# 1  48Z55      67318  Jeremy Bowers               20160101              gold

# %% [markdown]
# From the information provided by the witnesses, we have got two suspects, Joe Germuska and Jeremy Bowers.

# %% [markdown]
# #### 5. Check Car Details:
# Task: Examine the car details associated with the crime scene. Retrieve information about the vehicles present during the incident.

# %%
query8 = """
SELECT
* 
FROM 
drivers_license
WHERE
plate_number
LIKE
"%H42W%"
"""
pd.read_sql_query(query8,conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number   car_make  \
# 0  183779   21      65      blue     blonde  female       H42W0X     Toyota
# 1  423327   30      70     brown      brown    male       0H42W2  Chevrolet
# 2  664760   21      71     black      black    male       4H42WR     Nissan
#
#   car_model
# 0     Prius
# 1  Spark LS
# 2    Altima

# %% [markdown]
# #### Query 6. Personal Details:
# Task: Identify and collect personal details mentioned in the previous query. This includes names, addresses, and any additional details.

# %%
query9 = """
SELECT
* 
FROM 
interview
WHERE
person_id = 67318
"""
pd.read_sql_query(query9,conn)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
query10 = """
SELECT
* 
FROM 
drivers_license
WHERE
height IN(65,67)
AND
hair_color = "red"
"""
pd.read_sql_query(query10,conn)
# Out:
#         id  age  height eye_color hair_color  gender plate_number    car_make  \
# 0   121750   51      67     amber        red  female       555AGV  Volkswagen
# 1   131316   35      65     green        red    male       6XY025   Chevrolet
# 2   147044   42      67     black        red    male       6M5F67         BMW
# 3   171794   64      65     black        red    male       CF501D     Hyundai
# 4   173984   43      67     green        red    male       3Y8UC5     Pontiac
# ..     ...  ...     ...       ...        ...     ...          ...         ...
# 61  899992   47      65     amber        red  female       V34LP8      Suzuki
# 62  918773   48      65     black        red  female       917UU3       Tesla
# 63  928974   83      67     amber        red    male       EI4U5Z      Jaguar
# 64  982856   18      65     black        red  female       M1JZEQ   Chevrolet
# 65  998194   59      65     black        red  female       U85D0X  Mitsubishi
#
#            car_model
# 0            Phaeton
# 1        Trailblazer
# 2           3 Series
# 3           Santa Fe
# 4           Firebird
# ..               ...
# 61               SX4
# 62           Model S
# 63            X-Type
# 64  Silverado 3500HD
# 65  Lancer Evolution
#
# [66 rows x 9 columns]

# %%
query10 = """
SELECT
* 
FROM 
interview
WHERE
person_id = 67318
"""
pd.read_sql_query(query10,conn)
# Out:
#    person_id                                         transcript
# 0      67318  I was hired by a woman with a lot of money. I ...

# %%
query11 = """
SELECT
* 
FROM 
drivers_license
WHERE
height IN(65,66,67)
AND
hair_color = "red"
AND
car_make = "Tesla"
AND
car_model = "Model S"
"""
pd.read_sql_query(query11,conn)
# Out:
#        id  age  height eye_color hair_color  gender plate_number car_make  \
# 0  202298   68      66     green        red  female       500123    Tesla
# 1  291182   65      66      blue        red  female       08CM64    Tesla
# 2  918773   48      65     black        red  female       917UU3    Tesla
#
#   car_model
# 0   Model S
# 1   Model S
# 2   Model S

# %%
query12 = '''
SELECT *
FROM person
WHERE license_id = "202298" OR license_id = "291182" OR license_id = "918773";
'''
pd.read_sql_query(query12, conn)
# Out:
#       id              name  license_id  address_number address_street_name  \
# 0  78881          Red Korb      918773             107         Camerata Dr
# 1  90700     Regina George      291182             332           Maple Ave
# 2  99716  Miranda Priestly      202298            1883          Golden Ave
#
#          ssn
# 0  961388910
# 1  337169072
# 2  987756388

# %%
query13 = '''
SELECT 
person_id, count(*), event_name
FROM 
facebook_event_checkin
GROUP BY 
person_id
having count(*) = 3
AND 
event_name = "SQL Symphony Concert"
AND 
date
LIKE
"%201712%";
'''
pd.read_sql_query(query13, conn)
# Out:
#    person_id  count(*)            event_name
# 0      24556         3  SQL Symphony Concert
# 1      99716         3  SQL Symphony Concert

# %% [markdown]
# Thus, we found that "Miranda Priestly" is the mastermind behind the murder!
